# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 8))
a=0.386
b=0.01

posicao=[]
tempo=[]

eixo_x = [0.1100,0.2100,0.3100,0.4100,0.5100]
eixo_y = [0.2690,0.5220,0.7740,1.016,1.266]

for x in range(0,3):
  y=a*x+b 
  tempo.append(x)
  posicao.append(y)
 
plt.plot(eixo_x,eixo_y, 'r^')
plt.plot(posicao,tempo,lw=2)

plt.xlabel("Posição", fontsize='x-large')
plt.ylabel("Tempo", fontsize='x-large')
plt.title('Função Afim - MRU')
fig.savefig('graficoMRU.png')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 8))

velocidade=[]
tempo=[]

eixo_y = [0.3711,0.3832,0.3871,0.3943,0.3952]
eixo_x = [0.2690,0.5220,0.74740,1.016,1.266]

a=0
b=0.386
for x in range(0,3):
  y=a*x+b 
  tempo.append(x)
  velocidade.append(y)
 
plt.plot(eixo_x,eixo_y, 'r^')
plt.plot(tempo,velocidade,lw=2)

plt.xlabel("Tempo", fontsize='x-large')
plt.ylabel("Velocidade", fontsize='x-large')
plt.yticks(range(0, 2))
plt.title('Função Afim - MRU (2)')
fig.savefig('graficoMRU2.png')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 8))
a=0.564
b=0

forca=[]
aceleracao=[]

eixo_x = [0.50,0.64,0.83,1.06,1.21,1.548]
eixo_y = [0.1952,0.2928,0.3904,0.4880,0.5856,0.6832]

for x in range(0,3):
  y=a*x+b 
  aceleracao.append(x)
  forca.append(y)
 
plt.plot(eixo_x,eixo_y, 'r^')
plt.plot(aceleracao,forca,lw=2)

plt.xlabel("Aceleração", fontsize='x-large')
plt.ylabel("Força", fontsize='x-large')
plt.title('Função Afim - MRUV')
fig.savefig('graficoMRUV1.png')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 8))
a=0.1952
b=0

aceleracao=[]
massa=[]

massa1 = [0.5144,0.564,0.6155,0.6644,0.7144,0.7644]
massa_inversa = [(1/numero) for numero in massa1]

eixo_x = [0.424,0.422,0.376,0.335,0.322,0.301]
eixo_y = massa_inversa

for x in range(0,4):
  y=a*x+b 
  aceleracao.append(x)
  massa.append(y)
 
plt.plot(eixo_x,eixo_y, 'r^')
plt.plot(massa,aceleracao,lw=2)

plt.xlabel("Aceleração", fontsize='x-large')
plt.ylabel("Massa", fontsize='x-large')
plt.title('Função Afim - MRUV (2)')
fig.savefig('graficoMRUV2.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10, 8))
a=7.07
b=0

forca=[]
deformacao=[]

eixo_x = [0.0560,0.140,0.202,0.277,0.343,0.412]
eixo_y = [0.489,0.976,1.468,1.959,2.449,2.930]


for x in np.arange(0.0560, 0.55, 0.15):
  y=a*x+b 
  forca.append(x)
  deformacao.append(y)
 
plt.plot(eixo_x,eixo_y, 'r^')
plt.plot(forca,deformacao,lw=2)

plt.xlabel("Deformação (m)", fontsize='x-large')
plt.ylabel("Força (N)", fontsize='x-large')
plt.title('Lucas Kaminski | Gabriel Afonso | Saulo da Silva')
fig.savefig('graficoElastica.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10, 8))
a=7.23
b=0

forca=[]
deformacao=[]

eixo_x = [0.412,0.336,0.274,0.202,0.136,0.066]
eixo_y = [2.93,2.449,1.959,1.468,0.976,0.489]


for x in np.arange(0.0560, 0.55, 0.15):
  y=a*x+b 
  forca.append(x)
  deformacao.append(y)
 
plt.plot(eixo_x,eixo_y, 'r^')
plt.plot(forca,deformacao,lw=2)

plt.xlabel("Deformação (m)", fontsize='x-large')
plt.ylabel("Força (N)", fontsize='x-large')
plt.title('Lucas Kaminski | Gabriel Afonso | Saulo da Silva (2)')
fig.savefig('graficoElastica.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10, 8))
a=110.52
b=0

forca=[]
deformacao=[]

eixo_x = [0.004,0.011,0.013,0.017,0.022,0.026]
eixo_y = [0.489,0.976,1.468,1.959,2.449,2.93]


for x in np.arange(0.004, 0.03, 0.001):
  y=a*x+b 
  forca.append(x)
  deformacao.append(y)
 
plt.plot(eixo_x,eixo_y, 'r^')
plt.plot(forca,deformacao,lw=2)

plt.xlabel("Deformação (m)", fontsize='x-large')
plt.ylabel("Força (N)", fontsize='x-large')
plt.title('Lucas Kaminski | Gabriel Afonso | Saulo da Silva (3)')
fig.savefig('graficoElastica.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10, 8))
a=107.12
b=0

forca=[]
deformacao=[]

eixo_x = [0.026,0.02,0.016,0.014,0.012,0.005]
eixo_y = [2.93,2.449,1.959,1.468,0.976,0.489]


for x in np.arange(0.004, 0.03, 0.001):
  y=a*x+b 
  forca.append(x)
  deformacao.append(y)
 
plt.plot(eixo_x,eixo_y, 'r^')
plt.plot(forca,deformacao,lw=2)

plt.xlabel("Deformação (m)", fontsize='x-large')
plt.ylabel("Força (N)", fontsize='x-large')
plt.title('Lucas Kaminski | Gabriel Afonso | Saulo da Silva (4)')
fig.savefig('graficoElastica.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10, 8))
a=7.88
b=0

forca=[]
deformacao=[]

eixo_x = [0.058,0.124,0.190,0.252,0.317]
eixo_y = [0.488,0.976,1.464,1.952,2.440]


for x in np.arange(0.0, 0.317, 0.001):
  y=a*x+b 
  forca.append(x)
  deformacao.append(y)
 
plt.plot(eixo_x,eixo_y, 'r^')
plt.plot(forca,deformacao,lw=2)

plt.xlabel("Deformação (m)", fontsize='x-large')
plt.ylabel("Força (N)", fontsize='x-large')
plt.title('Lucas Kaminski | Saulo da Silva ')
fig.savefig('graficoElastica.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10, 8))
a=2.5
b=0.280

forca=[]
deformacao=[]

eixo_x = [0.504,0.554,0.604,0.654,0.704]
eixo_y = [1.6257,1.670,1.796,1.839,1.920]



for x in np.arange(0.0, 0.8, 0.001):
  y=a*x+b 
  forca.append(x)
  deformacao.append(y)
 
plt.plot(eixo_x,eixo_y, 'r^')
plt.plot(forca,deformacao,lw=2)

plt.xlabel("Periodo (s)", fontsize='x-large')
plt.ylabel("Massa (kg)", fontsize='x-large')
plt.title('Lucas Kaminski | Saulo da Silva ')
fig.savefig('graficoElastica.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10, 8))

a=1.12
b=0.955
forca=[]
deformacao=[]
for x in np.arange(0.0, 1.8, 0.001):
  y=a*x+b 
  forca.append(x)
  deformacao.append(y)
plt.plot(forca,deformacao, 'b-')

a=4.133
b=0
forca=[]
deformacao=[]
for x in np.arange(0.0, 1.8, 0.001):
  y=a*x+b 
  forca.append(x)
  deformacao.append(y)
plt.plot(forca,deformacao, '-')

eixo_x = [1.54,1.60,1.47,1.34,1.24,1.12,1.02,0.87]
eixo_y = [2.462,2.548,2.449,2.419,2.256,2.194,2.032,1.933]
plt.plot(eixo_x,eixo_y, 'r^', label="Periodo")

eixo_y2 = [6.061,6.492,5.99,5.851,4.85,4.81,4.12,3.76]
plt.plot(eixo_x,eixo_y2, 'bo', label="Periodo²")

plt.legend(loc="upper left")

plt.xlabel("Comprimento (m)", fontsize='x-large')
plt.ylabel("Periodo (s)", fontsize='x-large')
plt.title('Lucas Kaminski | Saulo da Silva ')

fig.savefig('graficoElastica.png')
