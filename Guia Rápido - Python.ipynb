# %%
nome = "Lucas Kaminski"
idade = 18

# %% [markdown]
# ##Acesso à documentação

# %%
#dir() é um resumo dos atributos e funções disponíveis
print(dir(nome))

nome.casefold()

# %%
#help() é uma explicação dos atributos e funções
help(type(nome))

# %% [markdown]
# ##Formatação 3.7

# %%
print(f"Seja bem vindo(a) {nome}, você nasceu em {2020 - int(idade)}")
# Out:
# Seja bem vindo(a) Lucas Kaminski, você nasceu em 2002

# %% [markdown]
# ##PEP-8

# %%
#Imports: um por linha
import sys
import os
from math import (
    py,
    sin
)

# %%
#Classes: Camel Case
class Calculadora:
  pass

# %%
#Funções e variaveis: snake case
def soma():
  pass

def soma_dois():
  pass

numero_dois_inteiro = 2

# %%
#Quatro espaços ou dois tab para cada indentação
def oi():
    print("Oi")

# %%
#Espaços em expressões e instruções
funcao(algo[1],{algo:2})
dict['Chave'] = Lista[Indice]

# %% [markdown]
# ##Tipos de variáveis
# *Antes locais e depois globais*

# %%
#Global
numero_global = 42
print(numero_global)

#Local
if numero_global > 10:
  numero_local = numero_global + 10
  print(numero_local)

# %%
#Nula
numeros = None
  #(Tratada como false)
  #if not numeros:
  # print("oi")

#Boolean bool()
ativo = True
desativo = False

#Inteiro int()
intz = 5

#Decimal float()
valor = 1.44
valor1, valor2 = 1.20, 1.22

#Complexo
numero_complexo = 5j

#String
nome = "Lucas Kaminski"

# %% [markdown]
# ##Operações

# %%
#Negação
not Ativo

#Ou
ativo or logado

#E
ativo and logado

# %%
#Comparações booleanas
5 > 6
5 < 6
6 == 6 #igual
6 <= 6 #menor ou igual
6 >= 6 #maior ou igual

# %%
#Operações numéricas
5/2 #"retorna float"
5//2 #"retorna int para baixo"
4%2 #"retorna resto"

num = 1 #1
num += 1 #2
num -= 1 #1
num *= 4 #4
print(num / 3)
print(num // 3)
# Out:
# 1.3333333333333333
# 1

# %%
#Operações com string

nome.split()
nome[0:4] #[inicial:final]
nome[::2] #[inicial:final:passo]

# %% [markdown]
# ##Laços estruturais

# %%
#Comparação lógica
Ativo = True
print(Ativo is False)

numeros = [1,0,2,6,4]
print(4 in numeros)
# Out:
# False
# True

# %%
#Se (condicional)
if idade < 12:
  print("Menor de idade")
elif idade == 18:
  print("Dezoitou")
elif idade == 20:
  print("hehe")
else:
  print("se foder")

#break: força o fim do laço
#pass:
# Out:
# se foder

# %%
#Para (tem argumento final)
for i in range(0,5,2):
  print(i)

#range(): lista numerica automatica | range(fim), range(inicio, fim), range(inicio, fim, passo)

# %%
#Enquanto (boolean)
numero = 1
while numero < 10:
  print(numero)
  numero += numero

# %% [markdown]
# ##Coleções de dados
